# %%
import pandas as pd

# %%
URL = 'https://raw.githubusercontent.com/andersoncordeiro/datasets/main/arq_municipios_fronteiricos.csv'

# %%
municipios = pd.read_csv(URL)

# %%
munc = "1 - Aceguá"
munc.split('-')[1]
# Out:
# ' Aceguá'

# %%
municipios['Município'] = municipios['Município'].str.replace('–', '-')

# %%
municipios['nome_municipio'] = municipios['Município'].apply(lambda x: x.split('-')[-1].strip())

# %%
municipios
# Out:
#                                   Município             Estado  \
# 0                                1 - Aceguá  Rio Grande do Sul
# 1                            2 - Acrelândia               Acre
# 2                               3 - Alecrim  Rio Grande do Sul
# 3                              4 - Almeirim               Pará
# 4                 5 - Alta Floresta d'Oeste           Rondônia
# ..                                      ...                ...
# 117                         118 - Tunápolis      Santa Cataria
# 118                          119 - Uiramutã            Roraima
# 119                        120 - Uruguaiana  Rio Grande do Sul
# 120  121 - Vila Bela da Santíssima Trindade        Mato Grosso
# 121                            122 - Xapuri               Acre
#
#      Área territorial  População (IBGE/2007) Densidade demográfica (hab/km2)  \
# 0               1.550                  4.138                            2,66
# 1               1.575                 11.520                            7,31
# 2             315.000                  7.357                           23,35
# 3              72.960                 30.903                            0,42
# 4               7.067                 23.857                            3,37
# ..                ...                    ...                             ...
# 117           133.000                  4.650                           34,96
# 118             8.066                  7.403                            0,91
# 119             5.716                123.743                           21,64
# 120            13.631                 13.886                            1,01
# 121             5.251                 14.314                            2,72
#
#     PIB (IBGE/2005 PIB per capita (R$) IDH/2000  \
# 0       71.638.000              17.266       ni
# 1      114.350.000               9.986    0,680
# 2       44.373.000               5.944    0,743
# 3      462.258.000              13.485    0,745
# 4      186.812.000               6.525    0,715
# ..             ...                 ...      ...
# 117     40.845.000               9.420    0,821
# 118     27.251.000               4.238    0,542
# 119  1.187.038.000               8.798    0,788
# 120    116.908.000               8.047    0,715
# 121     82.377.000               6.016    0,669
#
#                        nome_municipio
# 0                              Aceguá
# 1                          Acrelândia
# 2                             Alecrim
# 3                            Almeirim
# 4               Alta Floresta d'Oeste
# ..                                ...
# 117                         Tunápolis
# 118                          Uiramutã
# 119                        Uruguaiana
# 120  Vila Bela da Santíssima Trindade
# 121                            Xapuri
#
# [122 rows x 9 columns]

# %%
municipios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Município                        122 non-null    object
#  1   Estado                           122 non-null    object
#  2   Área territorial                 122 non-null    float64
#  3   População (IBGE/2007)            122 non-null    float64
#  4   Densidade demográfica (hab/km2)  122 non-null    object
#  5   PIB (IBGE/2005                   122 non-null    object
#  6   PIB per capita (R$)              122 non-null    object
#  7   IDH/2000                         122 non-null    object
#  8   nome_municipio                   122 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 8.7+ KB

# %%
municipios['Densidade demográfica (hab/km2)'].str.replace(',', '.').astype(float)
# Out:
# 0       2.66
# 1       7.31
# 2      23.35
# 3       0.42
# 4       3.37
#        ...
# 117    34.96
# 118     0.91
# 119    21.64
# 120     1.01
# 121     2.72
# Name: Densidade demográfica (hab/km2), Length: 122, dtype: float64

# %%
df_original = pd.read_csv(URL, thousands=".", decimal=",")

# %%
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Município                        122 non-null    object
#  1   Estado                           122 non-null    object
#  2   Área territorial                 122 non-null    int64
#  3   População (IBGE/2007)            122 non-null    int64
#  4   Densidade demográfica (hab/km2)  122 non-null    float64
#  5   PIB (IBGE/2005                   122 non-null    object
#  6   PIB per capita (R$)              122 non-null    object
#  7   IDH/2000                         122 non-null    object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 7.8+ KB

# %%
df_original
# Out:
#                                   Município             Estado  \
# 0                                1 – Aceguá  Rio Grande do Sul
# 1                            2 – Acrelândia               Acre
# 2                               3 – Alecrim  Rio Grande do Sul
# 3                              4 – Almeirim               Pará
# 4                 5 – Alta Floresta d'Oeste           Rondônia
# ..                                      ...                ...
# 117                         118 - Tunápolis      Santa Cataria
# 118                          119 - Uiramutã            Roraima
# 119                        120 - Uruguaiana  Rio Grande do Sul
# 120  121 - Vila Bela da Santíssima Trindade        Mato Grosso
# 121                            122 - Xapuri               Acre
#
#      Área territorial  População (IBGE/2007)  Densidade demográfica (hab/km2)  \
# 0                1550                   4138                             2.66
# 1                1575                  11520                             7.31
# 2                 315                   7357                            23.35
# 3               72960                  30903                             0.42
# 4                7067                  23857                             3.37
# ..                ...                    ...                              ...
# 117               133                   4650                            34.96
# 118              8066                   7403                             0.91
# 119              5716                 123743                            21.64
# 120             13631                  13886                             1.01
# 121              5251                  14314                             2.72
#
#     PIB (IBGE/2005 PIB per capita (R$) IDH/2000
# 0       71.638.000              17.266       ni
# 1      114.350.000               9.986    0,680
# 2       44.373.000               5.944    0,743
# 3      462.258.000              13.485    0,745
# 4      186.812.000               6.525    0,715
# ..             ...                 ...      ...
# 117     40.845.000               9.420    0,821
# 118     27.251.000               4.238    0,542
# 119  1.187.038.000               8.798    0,788
# 120    116.908.000               8.047    0,715
# 121     82.377.000               6.016    0,669
#
# [122 rows x 8 columns]

# %%
def converte_object_decimais(valor):
    return int(valor.replace(" ", "").replace(".",""))
              #.str.replace(' ','').str.replace('.','').astype(int)

# %%
df_original['PIB (IBGE/2005'] = df_original['PIB (IBGE/2005'].apply(converte_object_decimais)

# %%
df_original['PIB (IBGE/2005'] = df_original['PIB (IBGE/2005'].str.replace(' ','').str.replace('.','').astype(int)
# Out:
# /tmp/ipykernel_15317/2787648155.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_original['PIB (IBGE/2005'] = df_original['PIB (IBGE/2005'].str.replace(' ','').str.replace('.','').astype(int)

# %%
df_original
# Out:
#                                   Município             Estado  \
# 0                                1 – Aceguá  Rio Grande do Sul
# 1                            2 – Acrelândia               Acre
# 2                               3 – Alecrim  Rio Grande do Sul
# 3                              4 – Almeirim               Pará
# 4                 5 – Alta Floresta d'Oeste           Rondônia
# ..                                      ...                ...
# 117                         118 - Tunápolis      Santa Cataria
# 118                          119 - Uiramutã            Roraima
# 119                        120 - Uruguaiana  Rio Grande do Sul
# 120  121 - Vila Bela da Santíssima Trindade        Mato Grosso
# 121                            122 - Xapuri               Acre
#
#      Área territorial  População (IBGE/2007)  Densidade demográfica (hab/km2)  \
# 0                1550                   4138                             2.66
# 1                1575                  11520                             7.31
# 2                 315                   7357                            23.35
# 3               72960                  30903                             0.42
# 4                7067                  23857                             3.37
# ..                ...                    ...                              ...
# 117               133                   4650                            34.96
# 118              8066                   7403                             0.91
# 119              5716                 123743                            21.64
# 120             13631                  13886                             1.01
# 121              5251                  14314                             2.72
#
#      PIB (IBGE/2005 PIB per capita (R$) IDH/2000
# 0          71638000              17.266       ni
# 1         114350000               9.986    0,680
# 2          44373000               5.944    0,743
# 3         462258000              13.485    0,745
# 4         186812000               6.525    0,715
# ..              ...                 ...      ...
# 117        40845000               9.420    0,821
# 118        27251000               4.238    0,542
# 119      1187038000               8.798    0,788
# 120       116908000               8.047    0,715
# 121        82377000               6.016    0,669
#
# [122 rows x 8 columns]

# %%
df_original['PIB (IBGE/2005'] = df_original['PIB (IBGE/2005'].str.replace(' ','').str.replace('.','').astype(int)
df_original['PIB per capita (R$)'] = df_original['PIB per capita (R$)'].str.replace(' ','').str.replace('.','').astype(int)

# %%
#df_original['PIB (IBGE/2005'].apply(converte_object_decimais)
df_original['PIB per capita (R$)'] = df_original['PIB per capita (R$)'].apply(converte_object_decimais)

# %%
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Município                        122 non-null    object
#  1   Estado                           122 non-null    object
#  2   Área territorial                 122 non-null    int64
#  3   População (IBGE/2007)            122 non-null    int64
#  4   Densidade demográfica (hab/km2)  122 non-null    float64
#  5   PIB (IBGE/2005                   122 non-null    int64
#  6   PIB per capita (R$)              122 non-null    int64
#  7   IDH/2000                         122 non-null    object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 7.8+ KB

# %%
import numpy as np

# %%
df_original['IDH/2000'] = df_original['IDH/2000'].replace('ni', '0.621')
# FONTE: CLAUDIO PCICKASFIDKJSDAFIS

# %%
df_original['IDH/2000'] = df_original['IDH/2000'].str.replace(',','.').astype(float)

# %%
import unicodedata

# %%
def remove_acentos(texto):
    return unicodedata.normalize('NFKD', texto).encode('ascii', 'ignore').decode('ascii')

# %%
def normaliza_coluna(coluna):
    nova_coluna = coluna.replace(' (R$)', '').replace('/', '_').replace(' ', '_').replace('(', '').replace(')', '').lower()
    nova_coluna = remove_acentos(nova_coluna)
    return nova_coluna

# %%
novas_colunas = []
for column in df_original.columns:
    novas_colunas.append(normaliza_coluna(column))

# %%
novas_colunas = [normaliza_coluna(column) for column in df_original.columns]

# %%
novas_colunas
# Out:
# ['municipio',
#  'estado',
#  'area_territorial',
#  'populacao_ibge_2007',
#  'densidade_demografica_hab_km2',
#  'pib_ibge_2005',
#  'pib_per_capita',
#  'idh_2000']

# %%
def get_nome_municipio(texto):
    return texto.replace('–', '-').split('-')[-1].strip()

# %%
nome_municipio = '1 - Friburgo'

# %%
nome_municipio.split('-')[-1].strip()
# Out:
# 'Friburgo'

# %%
df_original.columns = novas_colunas

# %%
df_original['nome_municipio'] = df_original['municipio'].apply(get_nome_municipio)

# %%
df_original.columns
# Out:
# Index(['municipio', 'estado', 'area_territorial', 'populacao_ibge_2007',
#        'densidade_demografica_hab_km2', 'pib_ibge_2005', 'pib_per_capita',
#        'idh_2000', 'nome_municipio'],
#       dtype='object')

# %%
df_original = df_original[[
    'nome_municipio', 'estado', 'area_territorial', 'populacao_ibge_2007',
    'densidade_demografica_hab_km2', 'pib_ibge_2005', 'pib_per_capita', 'idh_2000'
]]

# %%
df_original
# Out:
#                        nome_municipio             estado  area_territorial  \
# 0                              Aceguá  Rio Grande do Sul              1550
# 1                          Acrelândia               Acre              1575
# 2                             Alecrim  Rio Grande do Sul               315
# 3                            Almeirim               Pará             72960
# 4               Alta Floresta d'Oeste           Rondônia              7067
# ..                                ...                ...               ...
# 117                         Tunápolis      Santa Cataria               133
# 118                          Uiramutã            Roraima              8066
# 119                        Uruguaiana  Rio Grande do Sul              5716
# 120  Vila Bela da Santíssima Trindade        Mato Grosso             13631
# 121                            Xapuri               Acre              5251
#
#      populacao_ibge_2007  densidade_demografica_hab_km2  pib_ibge_2005  \
# 0                   4138                           2.66       71638000
# 1                  11520                           7.31      114350000
# 2                   7357                          23.35       44373000
# 3                  30903                           0.42      462258000
# 4                  23857                           3.37      186812000
# ..                   ...                            ...            ...
# 117                 4650                          34.96       40845000
# 118                 7403                           0.91       27251000
# 119               123743                          21.64     1187038000
# 120                13886                           1.01      116908000
# 121                14314                           2.72       82377000
#
#      pib_per_capita  idh_2000
# 0             17266     0.621
# 1              9986     0.680
# 2              5944     0.743
# 3             13485     0.745
# 4              6525     0.715
# ..              ...       ...
# 117            9420     0.821
# 118            4238     0.542
# 119            8798     0.788
# 120            8047     0.715
# 121            6016     0.669
#
# [122 rows x 8 columns]

# %%
df_original.to_csv('municipios_cleaned.csv')

# %%
tab_order_review=tab_order_review[col[0:3]+[col[-1]]+col[4:7]]
