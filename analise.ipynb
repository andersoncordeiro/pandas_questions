# %%
import pandas as pd

# %%
df_products    = pd.read_csv('data/olist_products_dataset.csv') #read_sql(query)
df_order_items = pd.read_csv('data/olist_order_items_dataset.csv') #read_sql(query)
df_sellers     = pd.read_csv('data/olist_sellers_dataset.csv')

# %%
df_products.columns
# Out:
# Index(['product_id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm'],
#       dtype='object')

# %%
df_products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
df_order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
df_sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
df_products.merge(df_order_items, on='product_id')
# Out:
#                               product_id   product_category_name  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5              perfumaria
# 1       3aa071139cb16b67ca9e5dea641aaa2f                   artes
# 2       96bd76ec8810374ed1b65e291975717f           esporte_lazer
# 3       cef67bcfe19066a932b7673e239eb23d                   bebes
# 4       9dc1a7de274444849c219cff195d0b71   utilidades_domesticas
# ...                                  ...                     ...
# 112645  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112646  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112647  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112648  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112649  106392145fca363410d287a815be6de4         cama_mesa_banho
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                      40.0                       287.0                 1.0
# ...

# %%
df_products.rename(columns={'product_id':'id'}, inplace=True)

# %%
df_products
# Out:
#                                      id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
df_order_items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df_products_orders = df_products.merge(df_order_items, left_on='id', right_on='product_id')

# %%
df_sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
df_products_orders_sellers = df_products_orders.merge(df_sellers, on='seller_id')

# %%
df_products_orders_sellers.shape
# Out:
# (112650, 19)

# %%
df_products_orders_sellers
# Out:
#                                       id             product_category_name  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5                        perfumaria
# 1       a035b83b3628decee6e3823924e0c10f                        perfumaria
# 2       091107484dd7172f5dcfed173e4a960e                        perfumaria
# 3       ccac9976bafbf7e587bd2c29302e2314                        perfumaria
# 4       2eadf6089620e82047e4d24101dc6759                        perfumaria
# ...                                  ...                               ...
# 112645  daf9915404caf75fa1717a436b46fa14                  moveis_decoracao
# 112646  b0498e44190727b728ae4490f2e9b6a5                  malas_acessorios
# 112647  80b391b2dc6c958ef3ad34fa7ee01423                        automotivo
# 112648  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
# 112649  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
#
# ...

# %%
df_products_orders_sellers.columns
# Out:
# Index(['id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value',
#        'seller_zip_code_prefix', 'seller_city', 'seller_state'],
#       dtype='object')

# %%
df_products_orders_sellers['product_category_name']
# Out:
# 0                               perfumaria
# 1                               perfumaria
# 2                               perfumaria
# 3                               perfumaria
# 4                               perfumaria
#                         ...
# 112645                    moveis_decoracao
# 112646                    malas_acessorios
# 112647                          automotivo
# 112648    construcao_ferramentas_seguranca
# 112649    construcao_ferramentas_seguranca
# Name: product_category_name, Length: 112650, dtype: object

# %%
df_products_orders_sellers[['id', 'product_category_name']]
# Out:
#                                       id             product_category_name
# 0       1e9e8ef04dbcff4541ed26657ea517e5                        perfumaria
# 1       a035b83b3628decee6e3823924e0c10f                        perfumaria
# 2       091107484dd7172f5dcfed173e4a960e                        perfumaria
# 3       ccac9976bafbf7e587bd2c29302e2314                        perfumaria
# 4       2eadf6089620e82047e4d24101dc6759                        perfumaria
# ...                                  ...                               ...
# 112645  daf9915404caf75fa1717a436b46fa14                  moveis_decoracao
# 112646  b0498e44190727b728ae4490f2e9b6a5                  malas_acessorios
# 112647  80b391b2dc6c958ef3ad34fa7ee01423                        automotivo
# 112648  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
# 112649  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
#
# [112650 rows x 2 columns]

# %%
df_products_orders_sellers['product_category_name'].unique()
# Out:
# array(['perfumaria', 'artes', 'papelaria',
#        'construcao_ferramentas_construcao', 'artes_e_artesanato',
#        'esporte_lazer', 'fashion_bolsas_e_acessorios', 'bebes',
#        'utilidades_domesticas', 'informatica_acessorios',
#        'malas_acessorios', 'brinquedos', 'moveis_decoracao', 'automotivo',
#        'cama_mesa_banho', 'relogios_presentes',
#        'moveis_colchao_e_estofado', 'fashion_esporte',
#        'instrumentos_musicais', 'eletrodomesticos', 'climatizacao',
#        'eletrodomesticos_2', 'cool_stuff',
#        'construcao_ferramentas_jardim', 'musica', 'eletroportateis',
#        'ferramentas_jardim', 'portateis_casa_forno_e_cafe',
#        'consoles_games', 'alimentos', 'construcao_ferramentas_seguranca',
#        'telefonia', 'eletronicos', 'audio', 'beleza_saude',
#        'market_place', nan, 'fashion_roupa_infanto_juvenil',
#        'fashion_roupa_feminina', 'casa_construcao', 'telefonia_fixa',
# ...

# %%
df_products_orders_sellers
# Out:
#                                       id             product_category_name  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5                        perfumaria
# 1       a035b83b3628decee6e3823924e0c10f                        perfumaria
# 2       091107484dd7172f5dcfed173e4a960e                        perfumaria
# 3       ccac9976bafbf7e587bd2c29302e2314                        perfumaria
# 4       2eadf6089620e82047e4d24101dc6759                        perfumaria
# ...                                  ...                               ...
# 112645  daf9915404caf75fa1717a436b46fa14                  moveis_decoracao
# 112646  b0498e44190727b728ae4490f2e9b6a5                  malas_acessorios
# 112647  80b391b2dc6c958ef3ad34fa7ee01423                        automotivo
# 112648  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
# 112649  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
#
# ...

# %%
df_products_orders_sellers.groupby('product_category_name')['price'].mean()
# Out:
# product_category_name
# agro_industria_e_comercio    342.124858
# alimentos                     57.634137
# alimentos_bebidas             54.602446
# artes                        115.802105
# artes_e_artesanato            75.583750
#                                 ...
# sinalizacao_e_seguranca      108.086583
# tablets_impressao_imagem      90.703735
# telefonia                     71.213978
# telefonia_fixa               225.693182
# utilidades_domesticas         90.788148
# Name: price, Length: 73, dtype: float64

# %%
df_products_orders_sellers.groupby('product_category_name')['price'].mean().sort_values()
# Out:
# product_category_name
# casa_conforto_2                  25.342333
# flores                           33.637576
# fraldas_higiene                  40.194615
# cds_dvds_musicais                52.142857
# alimentos_bebidas                54.602446
#                                   ...
# instrumentos_musicais           281.616000
# agro_industria_e_comercio       342.124858
# eletrodomesticos_2              476.124958
# portateis_casa_forno_e_cafe     624.285658
# pcs                            1098.340542
# Name: price, Length: 73, dtype: float64

# %%
df_products_orders_sellers.groupby('product_category_name')['price'].mean().sort_values(ascending=False)
# Out:
# product_category_name
# pcs                            1098.340542
# portateis_casa_forno_e_cafe     624.285658
# eletrodomesticos_2              476.124958
# agro_industria_e_comercio       342.124858
# instrumentos_musicais           281.616000
#                                   ...
# alimentos_bebidas                54.602446
# cds_dvds_musicais                52.142857
# fraldas_higiene                  40.194615
# flores                           33.637576
# casa_conforto_2                  25.342333
# Name: price, Length: 73, dtype: float64

# %%
df_products_orders_sellers['product_category_name'].value_counts(normalize=True) * 100
# Out:
# cama_mesa_banho                  10.009275
# beleza_saude                      8.708025
# esporte_lazer                     7.781390
# moveis_decoracao                  7.504930
# informatica_acessorios            7.048367
#                                    ...
# la_cuisine                        0.012607
# cds_dvds_musicais                 0.012607
# pc_gamer                          0.008105
# fashion_roupa_infanto_juvenil     0.007204
# seguros_e_servicos                0.001801
# Name: product_category_name, Length: 73, dtype: float64

# %%
produtos_perfumaria = df_products_orders_sellers['product_category_name'] == 'perfumaria'

# %%
produtos_perfumaria
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 112645    False
# 112646    False
# 112647    False
# 112648    False
# 112649    False
# Name: product_category_name, Length: 112650, dtype: bool

# %%
produtos_perfumaria.sum()
# Out:
# 3419

# %%
df_products_orders_sellers[produtos_perfumaria].shape
# Out:
# (3419, 19)

# %%
df_products_orders_sellers[produtos_perfumaria]['price'].mean()
# Out:
# 116.73731207955544

# %%
df_products_orders_sellers[df_products_orders_sellers['product_category_name']=='perfumaria']
# Out:
#                                       id product_category_name  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5            perfumaria
# 1       a035b83b3628decee6e3823924e0c10f            perfumaria
# 2       091107484dd7172f5dcfed173e4a960e            perfumaria
# 3       ccac9976bafbf7e587bd2c29302e2314            perfumaria
# 4       2eadf6089620e82047e4d24101dc6759            perfumaria
# ...                                  ...                   ...
# 112507  7c900a8802a6e69db282513a6b159e70            perfumaria
# 112576  8bf16c54c7994478e4df5de5baf54e2f            perfumaria
# 112632  7dd3fec3502f7ef333da2a73e00db394            perfumaria
# 112633  7dd3fec3502f7ef333da2a73e00db394            perfumaria
# 112634  7dd3fec3502f7ef333da2a73e00db394            perfumaria
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                      40.0                       287.0                 1.0
# ...

# %%
df_products_orders_sellers.query("product_category_name == 'perfumaria'")
# Out:
#                                       id product_category_name  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5            perfumaria
# 1       a035b83b3628decee6e3823924e0c10f            perfumaria
# 2       091107484dd7172f5dcfed173e4a960e            perfumaria
# 3       ccac9976bafbf7e587bd2c29302e2314            perfumaria
# 4       2eadf6089620e82047e4d24101dc6759            perfumaria
# ...                                  ...                   ...
# 112507  7c900a8802a6e69db282513a6b159e70            perfumaria
# 112576  8bf16c54c7994478e4df5de5baf54e2f            perfumaria
# 112632  7dd3fec3502f7ef333da2a73e00db394            perfumaria
# 112633  7dd3fec3502f7ef333da2a73e00db394            perfumaria
# 112634  7dd3fec3502f7ef333da2a73e00db394            perfumaria
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                      40.0                       287.0                 1.0
# ...

# %%
produtos_perfumaria = df_products_orders_sellers['product_category_name'] == 'perfumaria'

# %%
df_products_orders_sellers[produtos_perfumaria]
# Out:
#                                       id product_category_name  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5            perfumaria
# 1       a035b83b3628decee6e3823924e0c10f            perfumaria
# 2       091107484dd7172f5dcfed173e4a960e            perfumaria
# 3       ccac9976bafbf7e587bd2c29302e2314            perfumaria
# 4       2eadf6089620e82047e4d24101dc6759            perfumaria
# ...                                  ...                   ...
# 112507  7c900a8802a6e69db282513a6b159e70            perfumaria
# 112576  8bf16c54c7994478e4df5de5baf54e2f            perfumaria
# 112632  7dd3fec3502f7ef333da2a73e00db394            perfumaria
# 112633  7dd3fec3502f7ef333da2a73e00db394            perfumaria
# 112634  7dd3fec3502f7ef333da2a73e00db394            perfumaria
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                      40.0                       287.0                 1.0
# ...

# %%
df_products_orders_sellers[df_products_orders_sellers['price'] > 100]
# Out:
#                                       id             product_category_name  \
# 1       a035b83b3628decee6e3823924e0c10f                        perfumaria
# 3       ccac9976bafbf7e587bd2c29302e2314                        perfumaria
# 6       ba63ad9eaf3dc6369f8187e7251c0870                        perfumaria
# 7       ba63ad9eaf3dc6369f8187e7251c0870                        perfumaria
# 10      d6c69817b519edddbf1b289631b7160e                        perfumaria
# ...                                  ...                               ...
# 112634  7dd3fec3502f7ef333da2a73e00db394                        perfumaria
# 112644  c1c4271977e10331523b010496ab2f9b                        brinquedos
# 112646  b0498e44190727b728ae4490f2e9b6a5                  malas_acessorios
# 112648  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
# 112649  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
#
# ...

# %%
produtos_acima_100 = df_products_orders_sellers['price'] > 100

# %%
df_products_orders_sellers[produtos_perfumaria & produtos_acima_100]
# Out:
#                                       id product_category_name  \
# 1       a035b83b3628decee6e3823924e0c10f            perfumaria
# 3       ccac9976bafbf7e587bd2c29302e2314            perfumaria
# 6       ba63ad9eaf3dc6369f8187e7251c0870            perfumaria
# 7       ba63ad9eaf3dc6369f8187e7251c0870            perfumaria
# 10      d6c69817b519edddbf1b289631b7160e            perfumaria
# ...                                  ...                   ...
# 112407  72b1dd0754a71db3f7b7dd8f776cd84a            perfumaria
# 112576  8bf16c54c7994478e4df5de5baf54e2f            perfumaria
# 112632  7dd3fec3502f7ef333da2a73e00db394            perfumaria
# 112633  7dd3fec3502f7ef333da2a73e00db394            perfumaria
# 112634  7dd3fec3502f7ef333da2a73e00db394            perfumaria
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# 1                      53.0                      2235.0                 3.0
# ...

# %%
df_products_orders_sellers[(df_products_orders_sellers['price'] > 100) & (df_products_orders_sellers['product_category_name'] == 'perfumaria')]
# Out:
#                                       id product_category_name  \
# 1       a035b83b3628decee6e3823924e0c10f            perfumaria
# 3       ccac9976bafbf7e587bd2c29302e2314            perfumaria
# 6       ba63ad9eaf3dc6369f8187e7251c0870            perfumaria
# 7       ba63ad9eaf3dc6369f8187e7251c0870            perfumaria
# 10      d6c69817b519edddbf1b289631b7160e            perfumaria
# ...                                  ...                   ...
# 112407  72b1dd0754a71db3f7b7dd8f776cd84a            perfumaria
# 112576  8bf16c54c7994478e4df5de5baf54e2f            perfumaria
# 112632  7dd3fec3502f7ef333da2a73e00db394            perfumaria
# 112633  7dd3fec3502f7ef333da2a73e00db394            perfumaria
# 112634  7dd3fec3502f7ef333da2a73e00db394            perfumaria
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# 1                      53.0                      2235.0                 3.0
# ...

# %%
df_products_orders_sellers.query("price > 100 & product_category_name == 'perfumaria'")
# Out:
#                                       id product_category_name  \
# 1       a035b83b3628decee6e3823924e0c10f            perfumaria
# 3       ccac9976bafbf7e587bd2c29302e2314            perfumaria
# 6       ba63ad9eaf3dc6369f8187e7251c0870            perfumaria
# 7       ba63ad9eaf3dc6369f8187e7251c0870            perfumaria
# 10      d6c69817b519edddbf1b289631b7160e            perfumaria
# ...                                  ...                   ...
# 112407  72b1dd0754a71db3f7b7dd8f776cd84a            perfumaria
# 112576  8bf16c54c7994478e4df5de5baf54e2f            perfumaria
# 112632  7dd3fec3502f7ef333da2a73e00db394            perfumaria
# 112633  7dd3fec3502f7ef333da2a73e00db394            perfumaria
# 112634  7dd3fec3502f7ef333da2a73e00db394            perfumaria
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# 1                      53.0                      2235.0                 3.0
# ...

# %%
df_products_orders_sellers[
    (df_products_orders_sellers['price'] > 100) & 
    (df_products_orders_sellers['product_category_name'] == 'perfumaria')
    ]
# Out:
#                                       id product_category_name  \
# 1       a035b83b3628decee6e3823924e0c10f            perfumaria
# 3       ccac9976bafbf7e587bd2c29302e2314            perfumaria
# 6       ba63ad9eaf3dc6369f8187e7251c0870            perfumaria
# 7       ba63ad9eaf3dc6369f8187e7251c0870            perfumaria
# 10      d6c69817b519edddbf1b289631b7160e            perfumaria
# ...                                  ...                   ...
# 112407  72b1dd0754a71db3f7b7dd8f776cd84a            perfumaria
# 112576  8bf16c54c7994478e4df5de5baf54e2f            perfumaria
# 112632  7dd3fec3502f7ef333da2a73e00db394            perfumaria
# 112633  7dd3fec3502f7ef333da2a73e00db394            perfumaria
# 112634  7dd3fec3502f7ef333da2a73e00db394            perfumaria
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# 1                      53.0                      2235.0                 3.0
# ...

# %%
limite_preco = 100
categoria = 'perfumaria'

# %%
df_products_orders_sellers[
    (df_products_orders_sellers['price'] > limite_preco) & 
    (df_products_orders_sellers['product_category_name'] == categoria)
    ]
# Out:
#                                       id product_category_name  \
# 1       a035b83b3628decee6e3823924e0c10f            perfumaria
# 3       ccac9976bafbf7e587bd2c29302e2314            perfumaria
# 6       ba63ad9eaf3dc6369f8187e7251c0870            perfumaria
# 7       ba63ad9eaf3dc6369f8187e7251c0870            perfumaria
# 10      d6c69817b519edddbf1b289631b7160e            perfumaria
# ...                                  ...                   ...
# 112407  72b1dd0754a71db3f7b7dd8f776cd84a            perfumaria
# 112576  8bf16c54c7994478e4df5de5baf54e2f            perfumaria
# 112632  7dd3fec3502f7ef333da2a73e00db394            perfumaria
# 112633  7dd3fec3502f7ef333da2a73e00db394            perfumaria
# 112634  7dd3fec3502f7ef333da2a73e00db394            perfumaria
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# 1                      53.0                      2235.0                 3.0
# ...

# %%
def filtra_categoria(df, categoria, limite_preco=0):
    return df[
            (df['price'] > limite_preco) & 
            (df['product_category_name'] == categoria)
            ]

# %%
categorias_filtradas = filtra_categoria(df_products_orders_sellers, 'perfumaria', 300)

# %%
categorias_filtradas.to_csv("resultado_filtro_categorias_perfumaria.csv")

# %%
df_products_orders_sellers
# Out:
#                                       id             product_category_name  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5                        perfumaria
# 1       a035b83b3628decee6e3823924e0c10f                        perfumaria
# 2       091107484dd7172f5dcfed173e4a960e                        perfumaria
# 3       ccac9976bafbf7e587bd2c29302e2314                        perfumaria
# 4       2eadf6089620e82047e4d24101dc6759                        perfumaria
# ...                                  ...                               ...
# 112645  daf9915404caf75fa1717a436b46fa14                  moveis_decoracao
# 112646  b0498e44190727b728ae4490f2e9b6a5                  malas_acessorios
# 112647  80b391b2dc6c958ef3ad34fa7ee01423                        automotivo
# 112648  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
# 112649  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
#
# ...

# %%
df_products_orders_sellers[
    (df_products_orders_sellers['price'] > limite_preco) |
    (df_products_orders_sellers['product_category_name'] == categoria)
    ]
# Out:
#                                       id             product_category_name  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5                        perfumaria
# 1       a035b83b3628decee6e3823924e0c10f                        perfumaria
# 2       091107484dd7172f5dcfed173e4a960e                        perfumaria
# 3       ccac9976bafbf7e587bd2c29302e2314                        perfumaria
# 4       2eadf6089620e82047e4d24101dc6759                        perfumaria
# ...                                  ...                               ...
# 112634  7dd3fec3502f7ef333da2a73e00db394                        perfumaria
# 112644  c1c4271977e10331523b010496ab2f9b                        brinquedos
# 112646  b0498e44190727b728ae4490f2e9b6a5                  malas_acessorios
# 112648  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
# 112649  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
#
# ...

# %%
df_products_orders_sellers[
    (df_products_orders_sellers['price'] > limite_preco) &
    (df_products_orders_sellers['product_category_name'] == categoria)
    ]
# Out:
#                                       id product_category_name  \
# 1       a035b83b3628decee6e3823924e0c10f            perfumaria
# 3       ccac9976bafbf7e587bd2c29302e2314            perfumaria
# 6       ba63ad9eaf3dc6369f8187e7251c0870            perfumaria
# 7       ba63ad9eaf3dc6369f8187e7251c0870            perfumaria
# 10      d6c69817b519edddbf1b289631b7160e            perfumaria
# ...                                  ...                   ...
# 112407  72b1dd0754a71db3f7b7dd8f776cd84a            perfumaria
# 112576  8bf16c54c7994478e4df5de5baf54e2f            perfumaria
# 112632  7dd3fec3502f7ef333da2a73e00db394            perfumaria
# 112633  7dd3fec3502f7ef333da2a73e00db394            perfumaria
# 112634  7dd3fec3502f7ef333da2a73e00db394            perfumaria
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# 1                      53.0                      2235.0                 3.0
# ...

# %%
df_products_orders_sellers[df_products_orders_sellers['product_category_name'] != 'perfumaria']
# Out:
#                                       id             product_category_name  \
# 22      3aa071139cb16b67ca9e5dea641aaa2f                             artes
# 23      aedb7e30007f6051c5b3f97156b0848a                             artes
# 24      a90344a21959338905811b0c0248ac4a                         papelaria
# 25      a90344a21959338905811b0c0248ac4a                         papelaria
# 26      737039cf7d608ac96fca4148ba80fcc0                         papelaria
# ...                                  ...                               ...
# 112645  daf9915404caf75fa1717a436b46fa14                  moveis_decoracao
# 112646  b0498e44190727b728ae4490f2e9b6a5                  malas_acessorios
# 112647  80b391b2dc6c958ef3ad34fa7ee01423                        automotivo
# 112648  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
# 112649  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
#
# ...

# %%
df_products_orders_sellers[~(df_products_orders_sellers['product_category_name'] == 'perfumaria')]
# Out:
#                                       id             product_category_name  \
# 22      3aa071139cb16b67ca9e5dea641aaa2f                             artes
# 23      aedb7e30007f6051c5b3f97156b0848a                             artes
# 24      a90344a21959338905811b0c0248ac4a                         papelaria
# 25      a90344a21959338905811b0c0248ac4a                         papelaria
# 26      737039cf7d608ac96fca4148ba80fcc0                         papelaria
# ...                                  ...                               ...
# 112645  daf9915404caf75fa1717a436b46fa14                  moveis_decoracao
# 112646  b0498e44190727b728ae4490f2e9b6a5                  malas_acessorios
# 112647  80b391b2dc6c958ef3ad34fa7ee01423                        automotivo
# 112648  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
# 112649  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
#
# ...

# %%
df_products_orders_sellers[
   ~((df_products_orders_sellers['price'] > limite_preco) &
    (df_products_orders_sellers['product_category_name'] == categoria))
    ]
# Out:
#                                       id             product_category_name  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5                        perfumaria
# 2       091107484dd7172f5dcfed173e4a960e                        perfumaria
# 4       2eadf6089620e82047e4d24101dc6759                        perfumaria
# 5       2e5cf3208803b03c62f319e2518e35c0                        perfumaria
# 8       d64e758afad411049a45e42c9a259241                        perfumaria
# ...                                  ...                               ...
# 112645  daf9915404caf75fa1717a436b46fa14                  moveis_decoracao
# 112646  b0498e44190727b728ae4490f2e9b6a5                  malas_acessorios
# 112647  80b391b2dc6c958ef3ad34fa7ee01423                        automotivo
# 112648  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
# 112649  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
#
# ...

# %%
top_100_price = df_products_orders_sellers[
    (df_products_orders_sellers['price'] > limite_preco) &
    (df_products_orders_sellers['product_category_name'] == categoria)
    ].sort_values('price').head(100)

# %%
df_products_orders_sellers[0:4][['product_name_lenght', 'price']]
# Out:
#    product_name_lenght   price
# 0                 40.0   10.91
# 1                 53.0  268.38
# 2                 50.0    7.65
# 3                 53.0  268.38

# %%
df_products_orders_sellers[['product_name_lenght', 'price']].head(4)
# Out:
#    product_name_lenght   price
# 0                 40.0   10.91
# 1                 53.0  268.38
# 2                 50.0    7.65
# 3                 53.0  268.38

# %%
df_products_orders_sellers
# Out:
#                                       id             product_category_name  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5                        perfumaria
# 1       a035b83b3628decee6e3823924e0c10f                        perfumaria
# 2       091107484dd7172f5dcfed173e4a960e                        perfumaria
# 3       ccac9976bafbf7e587bd2c29302e2314                        perfumaria
# 4       2eadf6089620e82047e4d24101dc6759                        perfumaria
# ...                                  ...                               ...
# 112645  daf9915404caf75fa1717a436b46fa14                  moveis_decoracao
# 112646  b0498e44190727b728ae4490f2e9b6a5                  malas_acessorios
# 112647  80b391b2dc6c958ef3ad34fa7ee01423                        automotivo
# 112648  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
# 112649  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
#
# ...

# %%
df_products_orders_sellers.iloc[0:4, 1:3]
# Out:
#   product_category_name  product_name_lenght
# 0            perfumaria                 40.0
# 1            perfumaria                 53.0
# 2            perfumaria                 50.0
# 3            perfumaria                 53.0

# %%
df_products_orders_sellers.set_index('product_category_name')
# Out:
#                                                                 id  \
# product_category_name
# perfumaria                        1e9e8ef04dbcff4541ed26657ea517e5
# perfumaria                        a035b83b3628decee6e3823924e0c10f
# perfumaria                        091107484dd7172f5dcfed173e4a960e
# perfumaria                        ccac9976bafbf7e587bd2c29302e2314
# perfumaria                        2eadf6089620e82047e4d24101dc6759
# ...                                                            ...
# moveis_decoracao                  daf9915404caf75fa1717a436b46fa14
# malas_acessorios                  b0498e44190727b728ae4490f2e9b6a5
# automotivo                        80b391b2dc6c958ef3ad34fa7ee01423
# construcao_ferramentas_seguranca  2b6535d32c6996c9478c131a8ff17a05
# construcao_ferramentas_seguranca  2b6535d32c6996c9478c131a8ff17a05
#
#                                   product_name_lenght  \
# product_category_name
# perfumaria                                       40.0
# ...

# %%
df_products_orders_sellers
# Out:
#                                       id             product_category_name  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5                        perfumaria
# 1       a035b83b3628decee6e3823924e0c10f                        perfumaria
# 2       091107484dd7172f5dcfed173e4a960e                        perfumaria
# 3       ccac9976bafbf7e587bd2c29302e2314                        perfumaria
# 4       2eadf6089620e82047e4d24101dc6759                        perfumaria
# ...                                  ...                               ...
# 112645  daf9915404caf75fa1717a436b46fa14                  moveis_decoracao
# 112646  b0498e44190727b728ae4490f2e9b6a5                  malas_acessorios
# 112647  80b391b2dc6c958ef3ad34fa7ee01423                        automotivo
# 112648  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
# 112649  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
#
# ...

# %%
df_products_orders_sellers.columns
# Out:
# Index(['id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value',
#        'seller_zip_code_prefix', 'seller_city', 'seller_state'],
#       dtype='object')

# %%
df_products_orders_sellers[['product_category_name', 'product_name_lenght', 'price']]
# Out:
#                    product_category_name  product_name_lenght   price
# 0                             perfumaria                 40.0   10.91
# 1                             perfumaria                 53.0  268.38
# 2                             perfumaria                 50.0    7.65
# 3                             perfumaria                 53.0  268.38
# 4                             perfumaria                 44.0   16.88
# ...                                  ...                  ...     ...
# 112645                  moveis_decoracao                 63.0   79.90
# 112646                  malas_acessorios                 25.0  199.99
# 112647                        automotivo                 17.0   29.90
# 112648  construcao_ferramentas_seguranca                 50.0  115.00
# 112649  construcao_ferramentas_seguranca                 50.0  115.00
#
# [112650 rows x 3 columns]

# %%
df_products_orders_sellers.iloc[0:4, [1, 2, 14]]
# Out:
#   product_category_name  product_name_lenght   price
# 0            perfumaria                 40.0   10.91
# 1            perfumaria                 53.0  268.38
# 2            perfumaria                 50.0    7.65
# 3            perfumaria                 53.0  268.38

# %%
df_products_orders_sellers.columns
# Out:
# Index(['id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value',
#        'seller_zip_code_prefix', 'seller_city', 'seller_state'],
#       dtype='object')

# %%
df_products_orders_sellers.iloc[0:4, [1, 2, -5]]
# Out:
#   product_category_name  product_name_lenght   price
# 0            perfumaria                 40.0   10.91
# 1            perfumaria                 53.0  268.38
# 2            perfumaria                 50.0    7.65
# 3            perfumaria                 53.0  268.38

# %%
df_products_orders_sellers.loc[i, j]

# %%
df_products_orders_sellers.head(2)
# Out:
#                                  id product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5            perfumaria
# 1  a035b83b3628decee6e3823924e0c10f            perfumaria
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 53.0                      2235.0                 3.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# 1            1450.0               20.0               25.0              20.0
#
#                            order_id  order_item_id  \
# 0  e17e4f88e31525f7deef66779844ddce              1
# 1  b18cb761efbe70da4838435a349abd07              1
#
#                          product_id                         seller_id  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5  5670f4db5b62c43d542e1b2d56b0cf7c
# ...

# %%
df_products_orders_sellers.iloc[ : , 1]
# Out:
# 0                               perfumaria
# 1                               perfumaria
# 2                               perfumaria
# 3                               perfumaria
# 4                               perfumaria
#                         ...
# 112645                    moveis_decoracao
# 112646                    malas_acessorios
# 112647                          automotivo
# 112648    construcao_ferramentas_seguranca
# 112649    construcao_ferramentas_seguranca
# Name: product_category_name, Length: 112650, dtype: object

# %%
df_products_orders_sellers.loc[ : ,'product_category_name']
# Out:
# 0                               perfumaria
# 1                               perfumaria
# 2                               perfumaria
# 3                               perfumaria
# 4                               perfumaria
#                         ...
# 112645                    moveis_decoracao
# 112646                    malas_acessorios
# 112647                          automotivo
# 112648    construcao_ferramentas_seguranca
# 112649    construcao_ferramentas_seguranca
# Name: product_category_name, Length: 112650, dtype: object

# %%
df_products_orders_sellers
# Out:
#                                       id             product_category_name  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5                        perfumaria
# 1       a035b83b3628decee6e3823924e0c10f                        perfumaria
# 2       091107484dd7172f5dcfed173e4a960e                        perfumaria
# 3       ccac9976bafbf7e587bd2c29302e2314                        perfumaria
# 4       2eadf6089620e82047e4d24101dc6759                        perfumaria
# ...                                  ...                               ...
# 112645  daf9915404caf75fa1717a436b46fa14                  moveis_decoracao
# 112646  b0498e44190727b728ae4490f2e9b6a5                  malas_acessorios
# 112647  80b391b2dc6c958ef3ad34fa7ee01423                        automotivo
# 112648  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
# 112649  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
#
# ...

# %%
df_products_orders_sellers.loc[1, 'product_name_lenght']
# Out:
# 53.0

# %%
df_temp = df_products_orders_sellers.groupby('product_category_name').mean()
# Out:
# /tmp/ipykernel_5240/1080863150.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_temp = df_products_orders_sellers.groupby('product_category_name').mean()

# %%
df_temp
# Out:
#                            product_name_lenght  product_description_lenght  \
# product_category_name
# agro_industria_e_comercio            46.735849                  865.518868
# alimentos                            48.796078                 1273.635294
# alimentos_bebidas                    43.579137                 1192.528777
# artes                                47.995215                  953.913876
# artes_e_artesanato                   46.791667                  792.208333
# ...                                        ...                         ...
# sinalizacao_e_seguranca              49.683417                  750.738693
# tablets_impressao_imagem             55.927711                  535.975904
# telefonia                            52.177338                  759.782398
# telefonia_fixa                       47.977273                  978.094697
# utilidades_domesticas                48.386416                  694.737364
#
# ...

# %%
df_temp.iloc[1, 0]
# Out:
# 48.79607843137255

# %%
df_temp.loc['alimentos', 'product_name_lenght']
# Out:
# 48.79607843137255

# %%
df_temp.loc[1, 'product_name_lenght']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/infnet/github/ingest-ecom/.ingest-ecom/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/infnet/github/ingest-ecom/.ingest-ecom/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/infnet/github/ingest-ecom/.ingest-ecom/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# ...

# %%
df_temp
# Out:
#                            product_name_lenght  product_description_lenght  \
# product_category_name
# agro_industria_e_comercio            46.735849                  865.518868
# alimentos                            48.796078                 1273.635294
# alimentos_bebidas                    43.579137                 1192.528777
# artes                                47.995215                  953.913876
# artes_e_artesanato                   46.791667                  792.208333
# ...                                        ...                         ...
# sinalizacao_e_seguranca              49.683417                  750.738693
# tablets_impressao_imagem             55.927711                  535.975904
# telefonia                            52.177338                  759.782398
# telefonia_fixa                       47.977273                  978.094697
# utilidades_domesticas                48.386416                  694.737364
#
# ...

# %%
df_temp.loc[['alimentos', 'artes'], ['product_name_lenght', 'product_description_lenght']]
# Out:
#                        product_name_lenght  product_description_lenght
# product_category_name
# alimentos                        48.796078                 1273.635294
# artes                            47.995215                  953.913876

# %%
df_temp.loc[['alimentos', 'artes']]
# Out:
#                        product_name_lenght  product_description_lenght  \
# product_category_name
# alimentos                        48.796078                 1273.635294
# artes                            47.995215                  953.913876
#
#                        product_photos_qty  product_weight_g  \
# product_category_name
# alimentos                        1.666667        658.115686
# artes                            1.889952       1557.545455
#
#                        product_length_cm  product_height_cm  product_width_cm  \
# product_category_name
# alimentos                      19.327451          13.666667         15.631373
# artes                          49.043062           8.535885         36.531100
#
#                        order_item_id       price  freight_value  \
# product_category_name
# alimentos                   1.194118   57.634137      14.256922
# artes                       1.100478  115.802105      19.354880
#
# ...

# %%
df_temp.reset_index(inplace=True)

# %%
df_temp
# Out:
#         product_category_name  product_name_lenght  \
# 0   agro_industria_e_comercio            46.735849
# 1                   alimentos            48.796078
# 2           alimentos_bebidas            43.579137
# 3                       artes            47.995215
# 4          artes_e_artesanato            46.791667
# ..                        ...                  ...
# 68    sinalizacao_e_seguranca            49.683417
# 69   tablets_impressao_imagem            55.927711
# 70                  telefonia            52.177338
# 71             telefonia_fixa            47.977273
# 72      utilidades_domesticas            48.386416
#
#     product_description_lenght  product_photos_qty  product_weight_g  \
# 0                   865.518868            2.349057       3625.113208
# 1                  1273.635294            1.666667        658.115686
# 2                  1192.528777            1.964029       1104.654676
# 3                   953.913876            1.889952       1557.545455
# ...

# %%
df_temp['new_column'] = 5

# %%
df_temp
# Out:
#         product_category_name  product_name_lenght  \
# 0   agro_industria_e_comercio            46.735849
# 1                   alimentos            48.796078
# 2           alimentos_bebidas            43.579137
# 3                       artes            47.995215
# 4          artes_e_artesanato            46.791667
# ..                        ...                  ...
# 68    sinalizacao_e_seguranca            49.683417
# 69   tablets_impressao_imagem            55.927711
# 70                  telefonia            52.177338
# 71             telefonia_fixa            47.977273
# 72      utilidades_domesticas            48.386416
#
#     product_description_lenght  product_photos_qty  product_weight_g  \
# 0                   865.518868            2.349057       3625.113208
# 1                  1273.635294            1.666667        658.115686
# 2                  1192.528777            1.964029       1104.654676
# 3                   953.913876            1.889952       1557.545455
# ...

# %%
df_temp.loc[:, 'seller_zip_code_prefix']
# Out:
# 0     47972.589623
# 1     16436.409804
# 2     21716.395683
# 3     23757.315789
# 4     17739.250000
#           ...
# 68    22201.542714
# 69     9418.843373
# 70    12792.084708
# 71    14047.571970
# 72    24610.842188
# Name: seller_zip_code_prefix, Length: 73, dtype: float64

# %%
df_temp.iloc[:, -1]
# Out:
# 0     5
# 1     5
# 2     5
# 3     5
# 4     5
#      ..
# 68    5
# 69    5
# 70    5
# 71    5
# 72    5
# Name: new_column, Length: 73, dtype: int64

# %%
df_temp
# Out:
#         product_category_name  product_name_lenght  \
# 0   agro_industria_e_comercio            46.735849
# 1                   alimentos            48.796078
# 2           alimentos_bebidas            43.579137
# 3                       artes            47.995215
# 4          artes_e_artesanato            46.791667
# ..                        ...                  ...
# 68    sinalizacao_e_seguranca            49.683417
# 69   tablets_impressao_imagem            55.927711
# 70                  telefonia            52.177338
# 71             telefonia_fixa            47.977273
# 72      utilidades_domesticas            48.386416
#
#     product_description_lenght  product_photos_qty  product_weight_g  \
# 0                   865.518868            2.349057       3625.113208
# 1                  1273.635294            1.666667        658.115686
# 2                  1192.528777            1.964029       1104.654676
# 3                   953.913876            1.889952       1557.545455
# ...

# %%
df_temp['price_0.1'] = df_temp['price'] * 0.1

# %%
df_temp
# Out:
#         product_category_name  product_name_lenght  \
# 0   agro_industria_e_comercio            46.735849
# 1                   alimentos            48.796078
# 2           alimentos_bebidas            43.579137
# 3                       artes            47.995215
# 4          artes_e_artesanato            46.791667
# ..                        ...                  ...
# 68    sinalizacao_e_seguranca            49.683417
# 69   tablets_impressao_imagem            55.927711
# 70                  telefonia            52.177338
# 71             telefonia_fixa            47.977273
# 72      utilidades_domesticas            48.386416
#
#     product_description_lenght  product_photos_qty  product_weight_g  \
# 0                   865.518868            2.349057       3625.113208
# 1                  1273.635294            1.666667        658.115686
# 2                  1192.528777            1.964029       1104.654676
# 3                   953.913876            1.889952       1557.545455
# ...

# %%
df_temp['new_price'] = df_temp['price'] - df_temp['price_0.1']

# %%
df_temp
# Out:
#         product_category_name  product_name_lenght  \
# 0   agro_industria_e_comercio            46.735849
# 1                   alimentos            48.796078
# 2           alimentos_bebidas            43.579137
# 3                       artes            47.995215
# 4          artes_e_artesanato            46.791667
# ..                        ...                  ...
# 68    sinalizacao_e_seguranca            49.683417
# 69   tablets_impressao_imagem            55.927711
# 70                  telefonia            52.177338
# 71             telefonia_fixa            47.977273
# 72      utilidades_domesticas            48.386416
#
#     product_description_lenght  product_photos_qty  product_weight_g  \
# 0                   865.518868            2.349057       3625.113208
# 1                  1273.635294            1.666667        658.115686
# 2                  1192.528777            1.964029       1104.654676
# 3                   953.913876            1.889952       1557.545455
# ...

# %%
df_temp[['product_category_name', 'new_price']].sort_values('new_price').iloc[0]
# Out:
# product_category_name    casa_conforto_2
# new_price                        22.8081
# Name: 15, dtype: object

# %%
df_products_orders_sellers.shape
# Out:
# (112650, 19)

# %%
df_products_orders_sellers.iloc[:, 9]
# Out:
# 0         14.0
# 1         20.0
# 2         13.0
# 3         20.0
# 4         14.0
#           ...
# 112645    30.0
# 112646    40.0
# 112647    13.0
# 112648    10.0
# 112649    10.0
# Name: product_width_cm, Length: 112650, dtype: float64

# %%
df_products_orders_sellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112650 entries, 0 to 112649
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   id                          112650 non-null  object
#  1   product_category_name       111047 non-null  object
#  2   product_name_lenght         111047 non-null  float64
#  3   product_description_lenght  111047 non-null  float64
#  4   product_photos_qty          111047 non-null  float64
#  5   product_weight_g            112632 non-null  float64
#  6   product_length_cm           112632 non-null  float64
#  7   product_height_cm           112632 non-null  float64
#  8   product_width_cm            112632 non-null  float64
#  9   order_id                    112650 non-null  object
#  10  order_item_id               112650 non-null  int64
#  11  product_id                  112650 non-null  object
# ...

# %%
df_products_orders_sellers.isnull().sum()
# Out:
# id                               0
# product_category_name         1603
# product_name_lenght           1603
# product_description_lenght    1603
# product_photos_qty            1603
# product_weight_g                18
# product_length_cm               18
# product_height_cm               18
# product_width_cm                18
# order_id                         0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# shipping_limit_date              0
# price                            0
# freight_value                    0
# seller_zip_code_prefix           0
# seller_city                      0
# seller_state                     0
# dtype: int64

# %%
df_products_orders_sellers.columns
# Out:
# Index(['id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value',
#        'seller_zip_code_prefix', 'seller_city', 'seller_state'],
#       dtype='object')

# %%
df_products_orders_sellers = df_products_orders_sellers[['id', 'order_id', 'product_category_name', 'product_name_lenght',
       'product_description_lenght', 'product_photos_qty', 'product_weight_g',
       'product_length_cm', 'product_height_cm', 'product_width_cm',
        'order_item_id', 'product_id', 'seller_id',
       'shipping_limit_date', 'price', 'freight_value',
       'seller_zip_code_prefix', 'seller_city', 'seller_state']]

# %%
df_products_orders_sellers
# Out:
#                                       id                          order_id  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5  e17e4f88e31525f7deef66779844ddce
# 1       a035b83b3628decee6e3823924e0c10f  b18cb761efbe70da4838435a349abd07
# 2       091107484dd7172f5dcfed173e4a960e  a7708ffa8966514c098d15e1abfa6417
# 3       ccac9976bafbf7e587bd2c29302e2314  206d1a13596872a713dba14504fdf699
# 4       2eadf6089620e82047e4d24101dc6759  f8bb4d404d187c79b86ccf852dfa345e
# ...                                  ...                               ...
# 112645  daf9915404caf75fa1717a436b46fa14  5d36e8ca3ccd1262b7641467fdba0b8e
# 112646  b0498e44190727b728ae4490f2e9b6a5  8edaa376e19d08bc84ab8845682216b4
# 112647  80b391b2dc6c958ef3ad34fa7ee01423  635c8d3ab47b7448b5d6c81dc9b7526e
# 112648  2b6535d32c6996c9478c131a8ff17a05  b3e5d245a95dd6378330cc2249d9d6b4
# 112649  2b6535d32c6996c9478c131a8ff17a05  b3e5d245a95dd6378330cc2249d9d6b4
#
#                    product_category_name  product_name_lenght  \
# ...

# %%
df_products_orders_sellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112650 entries, 0 to 112649
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   id                          112650 non-null  object
#  1   order_id                    112650 non-null  object
#  2   product_category_name       111047 non-null  object
#  3   product_name_lenght         111047 non-null  float64
#  4   product_description_lenght  111047 non-null  float64
#  5   product_photos_qty          111047 non-null  float64
#  6   product_weight_g            112632 non-null  float64
#  7   product_length_cm           112632 non-null  float64
#  8   product_height_cm           112632 non-null  float64
#  9   product_width_cm            112632 non-null  float64
#  10  order_item_id               112650 non-null  int64
#  11  product_id                  112650 non-null  object
# ...

# %%
df_products_orders_sellers[df_products_orders_sellers['product_category_name'].isnull()]
# Out:
#                                       id                          order_id  \
# 2860    e948cf75e6b64307f7f76a49eaa9fc2f  b11d3d0805ee25a1ca5ff9d55a65cd9d
# 5837    1dcd65bb5dd967d7b4c6b0223cefb838  a338e253d44a1df47d96f51106cf74dc
# 5858    e3e0c67c30ba9f25ab3a0f8e293737ed  9ea6d21c1c1b510f96f7917419175197
# 5879    986551a629c57419d4d2b74cdefc34dd  775747dc325485aedc9970fb0eda8b86
# 8531    f58e45b16a42a325c144eb2c46a2bc57  047723564a4f371af7f16f08f08ae0e0
# ...                                  ...                               ...
# 112538  4754922e24570093f580454e5920cd34  2f79d47add1e4f50799767e3088e9630
# 112541  3fc7f2008dc11b252c0f0e51a7bea4d6  6667ce63925742278c4eb0f5d83a913c
# 112571  aa52785e49f7b78b96704df4068d9e3d  7e843e422a53b8895473162e13c2b70f
# 112572  aa52785e49f7b78b96704df4068d9e3d  d86c683d3790be2beffa016e4140940d
# 112575  0ba14c257ad706bacadec65dfdb3b740  c8897b5891a3195ee9cecf410341b589
#
# ...

# %%
df_products_orders_sellers['product_photos_qty']
# Out:
# 0         1.0
# 1         3.0
# 2         2.0
# 3         3.0
# 4         1.0
#          ...
# 112645    5.0
# 112646    4.0
# 112647    4.0
# 112648    2.0
# 112649    2.0
# Name: product_photos_qty, Length: 112650, dtype: float64

# %%
df_products_orders_sellers['product_photos_qty'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[164], line 1
# ----> 1 df_products_orders_sellers['product_photos_qty'].astype('int')
#
# File ~/infnet/github/ingest-ecom/.ingest-ecom/lib/python3.10/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# ...

# %%
df_products_orders_sellers[~df_products_orders_sellers['product_photos_qty'].isnull()]
# Out:
#                                       id                          order_id  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5  e17e4f88e31525f7deef66779844ddce
# 1       a035b83b3628decee6e3823924e0c10f  b18cb761efbe70da4838435a349abd07
# 2       091107484dd7172f5dcfed173e4a960e  a7708ffa8966514c098d15e1abfa6417
# 3       ccac9976bafbf7e587bd2c29302e2314  206d1a13596872a713dba14504fdf699
# 4       2eadf6089620e82047e4d24101dc6759  f8bb4d404d187c79b86ccf852dfa345e
# ...                                  ...                               ...
# 112645  daf9915404caf75fa1717a436b46fa14  5d36e8ca3ccd1262b7641467fdba0b8e
# 112646  b0498e44190727b728ae4490f2e9b6a5  8edaa376e19d08bc84ab8845682216b4
# 112647  80b391b2dc6c958ef3ad34fa7ee01423  635c8d3ab47b7448b5d6c81dc9b7526e
# 112648  2b6535d32c6996c9478c131a8ff17a05  b3e5d245a95dd6378330cc2249d9d6b4
# 112649  2b6535d32c6996c9478c131a8ff17a05  b3e5d245a95dd6378330cc2249d9d6b4
#
#                    product_category_name  product_name_lenght  \
# ...

# %%
df_products_orders_sellers
# Out:
#                                       id             product_category_name  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5                        perfumaria
# 1       a035b83b3628decee6e3823924e0c10f                        perfumaria
# 2       091107484dd7172f5dcfed173e4a960e                        perfumaria
# 3       ccac9976bafbf7e587bd2c29302e2314                        perfumaria
# 4       2eadf6089620e82047e4d24101dc6759                        perfumaria
# ...                                  ...                               ...
# 112645  daf9915404caf75fa1717a436b46fa14                  moveis_decoracao
# 112646  b0498e44190727b728ae4490f2e9b6a5                  malas_acessorios
# 112647  80b391b2dc6c958ef3ad34fa7ee01423                        automotivo
# 112648  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
# 112649  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
#
# ...

# %%
"SELECT COUNT(id) as qtd, seller_city FROM tabela WHERE seller_state = 'SP'  GROUP BY seller_city ORDER BY qtd DESC "

# %%
sp_state = df_products_orders_sellers['seller_state']=='SP'

# %%
df_products_orders_sellers[sp_state]['seller_city'].value_counts(normalize=True) * 100
# Out:
# sao paulo                34.829852
# ibitinga                  9.646262
# santo andre               3.689229
# sao jose do rio preto     3.210027
# guarulhos                 2.939932
#                            ...
# sbc                       0.001245
# guaratingueta             0.001245
# sao paulo sp              0.001245
# londrina                  0.001245
# pitangueiras              0.001245
# Name: seller_city, Length: 261, dtype: float64

# %%
cidades = df_products_orders_sellers['seller_city'].value_counts(normalize=True) * 100

# %%
cidades > 5
# Out:
# sao paulo            True
# ibitinga             True
# curitiba            False
# santo andre         False
# belo horizonte      False
#                     ...
# campos novos        False
# tres coroas         False
# resende             False
# cordilheira alta    False
# campanha            False
# Name: seller_city, Length: 611, dtype: bool

# %%
cidades[cidades > 5]
# Out:
# sao paulo    24.840657
# ibitinga      6.879716
# Name: seller_city, dtype: float64

# %%
(df_products_orders_sellers['seller_city'].value_counts(normalize=True) * 100)[df_products_orders_sellers['seller_city'].value_counts(normalize=True) * 100 > 5]
# Out:
# sao paulo    24.840657
# ibitinga      6.879716
# Name: seller_city, dtype: float64

# %%
df_products_orders_sellers
# Out:
#                                       id             product_category_name  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5                        perfumaria
# 1       a035b83b3628decee6e3823924e0c10f                        perfumaria
# 2       091107484dd7172f5dcfed173e4a960e                        perfumaria
# 3       ccac9976bafbf7e587bd2c29302e2314                        perfumaria
# 4       2eadf6089620e82047e4d24101dc6759                        perfumaria
# ...                                  ...                               ...
# 112645  daf9915404caf75fa1717a436b46fa14                  moveis_decoracao
# 112646  b0498e44190727b728ae4490f2e9b6a5                  malas_acessorios
# 112647  80b391b2dc6c958ef3ad34fa7ee01423                        automotivo
# 112648  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
# 112649  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
#
# ...

# %%
df_products_orders_sellers
# Out:
#                                       id             product_category_name  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5                        perfumaria
# 1       a035b83b3628decee6e3823924e0c10f                        perfumaria
# 2       091107484dd7172f5dcfed173e4a960e                        perfumaria
# 3       ccac9976bafbf7e587bd2c29302e2314                        perfumaria
# 4       2eadf6089620e82047e4d24101dc6759                        perfumaria
# ...                                  ...                               ...
# 112645  daf9915404caf75fa1717a436b46fa14                  moveis_decoracao
# 112646  b0498e44190727b728ae4490f2e9b6a5                  malas_acessorios
# 112647  80b391b2dc6c958ef3ad34fa7ee01423                        automotivo
# 112648  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
# 112649  2b6535d32c6996c9478c131a8ff17a05  construcao_ferramentas_seguranca
#
# ...
