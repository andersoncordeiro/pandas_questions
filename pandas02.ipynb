# %%
import pandas as pd

# %% [markdown]
# ### Dicionário de Dados
#
# - Symboling 				Its assigned insurance risk rating, A value of +3 indicates that the auto is risky, -3 that it is probably pretty safe.(Categorical)
# - carCompany				Name of car company (Categorical)
# - fueltype				Car fuel type i.e gas or diesel (Categorical)
# - aspiration				Aspiration used in a car (Categorical)
# - doornumber				Number of doors in a car (Categorical)
# - carbody				body of car (Categorical)
# - drivewheel				type of drive wheel (Categorical)
# - enginelocation				Location of car engine (Categorical)
# - wheelbase				Weelbase of car (Numeric)
# - carlength				Length of car (Numeric)
# - carwidth				Width of car (Numeric)
# - carheight				height of car (Numeric)
# - curbweight				The weight of a car without occupants or baggage. (Numeric)
# - enginetype				Type of engine. (Categorical)
# - cylindernumber				cylinder placed in the car (Categorical)
# - enginesize				Size of car (Numeric)
# - fuelsystem				Fuel system of car (Categorical)
# - boreratio				Boreratio of car (Numeric)
# - stroke				Stroke or volume inside the engine (Numeric)
# - compressionratio				compression ratio of car (Numeric)
# - horsepower				Horsepower (Numeric)
# - peakrpm				car peak rpm (Numeric)
# - citympg				Mileage in city (Numeric)
# - highwaympg				Mileage on highway (Numeric)
# - price(Dependent variable)				Price of car (Numeric)

# %%
df = pd.read_csv('cars.csv', sep=',')

# %%
cars = df.copy()

# %%
cars.drop('Unnamed: 0', axis=1, inplace=True)

# %%
#cars.drop(columns=['Unnamed: 0'], axis=1)

# %%
cars.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
cars.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
pd.set_option("display.max_columns", None)

# %%
for column in cars.columns:
    print(f"\n {column.upper()}")
    print(cars[column].unique())
# Out:
#  SYMBOLING
# [ 3  1  2  0 -1 -2]
#
#  NORMALIZED-LOSSES
# ['?' '164' '158' '192' '188' '121' '98' '81' '118' '148' '110' '145' '137'
#  '101' '78' '106' '85' '107' '104' '113' '150' '129' '115' '93' '142'
#  '161' '153' '125' '128' '122' '103' '168' '108' '194' '231' '119' '154'
#  '74' '186' '83' '102' '89' '87' '77' '91' '134' '65' '197' '90' '94'
#  '256' '95']
#
#  MAKE
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']
#
#  FUEL-TYPE
# ['gas' 'diesel']
#
#  ASPIRATION
# ['std' 'turbo']
#
#  NUM-OF-DOORS
# ['two' 'four' '?']
#
#  BODY-STYLE
# ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
#
#  DRIVE-WHEELS
# ['rwd' 'fwd' '4wd']
#
#  ENGINE-LOCATION
# ['front' 'rear']
#
#  WHEEL-BASE
# [ 88.6  94.5  99.8  99.4 105.8  99.5 101.2 103.5 110.   88.4  93.7 103.3
# ...

# %%
cars['normalized-losses'].unique()
# Out:
# array(['?', '164', '158', '192', '188', '121', '98', '81', '118', '148',
#        '110', '145', '137', '101', '78', '106', '85', '107', '104', '113',
#        '150', '129', '115', '93', '142', '161', '153', '125', '128',
#        '122', '103', '168', '108', '194', '231', '119', '154', '74',
#        '186', '83', '102', '89', '87', '77', '91', '134', '65', '197',
#        '90', '94', '256', '95'], dtype=object)

# %%
import numpy as np

# %%
cars.replace('?', np.NaN, inplace=True)

# %%
for column in cars.columns:
    print(f"\n {column.upper()}")
    print(cars[column].unique())
# Out:
#  SYMBOLING
# [ 3  1  2  0 -1 -2]
#
#  NORMALIZED-LOSSES
# [nan '164' '158' '192' '188' '121' '98' '81' '118' '148' '110' '145' '137'
#  '101' '78' '106' '85' '107' '104' '113' '150' '129' '115' '93' '142'
#  '161' '153' '125' '128' '122' '103' '168' '108' '194' '231' '119' '154'
#  '74' '186' '83' '102' '89' '87' '77' '91' '134' '65' '197' '90' '94'
#  '256' '95']
#
#  MAKE
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']
#
#  FUEL-TYPE
# ['gas' 'diesel']
#
#  ASPIRATION
# ['std' 'turbo']
#
#  NUM-OF-DOORS
# ['two' 'four' nan]
#
#  BODY-STYLE
# ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
#
#  DRIVE-WHEELS
# ['rwd' 'fwd' '4wd']
#
#  ENGINE-LOCATION
# ['front' 'rear']
#
#  WHEEL-BASE
# [ 88.6  94.5  99.8  99.4 105.8  99.5 101.2 103.5 110.   88.4  93.7 103.3
# ...

# %%
cars.isnull().sum().sort_values(ascending=False)
# Out:
# normalized-losses    41
# price                 4
# stroke                4
# bore                  4
# peak-rpm              2
# num-of-doors          2
# horsepower            2
# engine-type           0
# highway-mpg           0
# city-mpg              0
# compression-ratio     0
# fuel-system           0
# engine-size           0
# num-of-cylinders      0
# symboling             0
# height                0
# width                 0
# length                0
# wheel-base            0
# engine-location       0
# drive-wheels          0
# body-style            0
# aspiration            0
# fuel-type             0
# make                  0
# curb-weight           0
# dtype: int64

# %%
cars
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
cars[['normalized-losses', 'width']] = cars[['normalized-losses', 'width']].astype(float)

# %%
avg_normalized_losses = cars['normalized-losses'].astype(float).mean()

# %%
avg_normalized_losses
# Out:
# 122.0

# %%
cars['normalized-losses'].replace(np.NaN, avg_normalized_losses)
# Out:
# 0      122.0
# 1      122.0
# 2      122.0
# 3      164.0
# 4      164.0
#        ...
# 200     95.0
# 201     95.0
# 202     95.0
# 203     95.0
# 204     95.0
# Name: normalized-losses, Length: 205, dtype: float64

# %%
cars['normalized-losses'].fillna(avg_normalized_losses)
# Out:
# 0      122.0
# 1      122.0
# 2      122.0
# 3      164.0
# 4      164.0
#        ...
# 200     95.0
# 201     95.0
# 202     95.0
# 203     95.0
# 204     95.0
# Name: normalized-losses, Length: 205, dtype: float64

# %%
cars['normalized-losses'].dropna()
# Out:
# 3      164.0
# 4      164.0
# 6      158.0
# 8      158.0
# 10     192.0
#        ...
# 200     95.0
# 201     95.0
# 202     95.0
# 203     95.0
# 204     95.0
# Name: normalized-losses, Length: 164, dtype: float64

# %%
cars[['normalized-losses', 'make', 'aspiration']]
# Out:
#      normalized-losses         make aspiration
# 0                  NaN  alfa-romero        std
# 1                  NaN  alfa-romero        std
# 2                  NaN  alfa-romero        std
# 3                164.0         audi        std
# 4                164.0         audi        std
# ..                 ...          ...        ...
# 200               95.0        volvo        std
# 201               95.0        volvo      turbo
# 202               95.0        volvo        std
# 203               95.0        volvo      turbo
# 204               95.0        volvo      turbo
#
# [205 rows x 3 columns]

# %%
colunas = list(cars.columns)
colunas.remove('make')
cars.dropna(subset=colunas,  axis=0)
# Out:
#      symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 3            2              164.0   audi       gas        std         four
# 4            2              164.0   audi       gas        std         four
# 6            1              158.0   audi       gas        std         four
# 8            1              158.0   audi       gas      turbo         four
# 10           2              192.0    bmw       gas        std          two
# ..         ...                ...    ...       ...        ...          ...
# 200         -1               95.0  volvo       gas        std         four
# 201         -1               95.0  volvo       gas      turbo         four
# 202         -1               95.0  volvo       gas        std         four
# 203         -1               95.0  volvo    diesel      turbo         four
# 204         -1               95.0  volvo       gas      turbo         four
#
# ...

# %%
cars
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 2            1                NaN  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1               95.0        volvo       gas        std
# 201         -1               95.0        volvo       gas      turbo
# 202         -1               95.0        volvo       gas        std
# 203         -1               95.0        volvo    diesel      turbo
# 204         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
cars.__dict__
# Out:
# {'_is_copy': None,
#  '_mgr': BlockManager
#  Items: Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#         'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#         'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#         'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#         'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#         'highway-mpg', 'price'],
#        dtype='object')
#  Axis 1: RangeIndex(start=0, stop=205, step=1)
#  NumericBlock: [ 1  9 10 11 12 20], 6 x 205, dtype: float64
#  NumericBlock: [ 0 13 16 23 24], 5 x 205, dtype: int64
#  ObjectBlock: [ 2  3  4  5  6  7  8 14 15 17 18 19 21 22 25], 15 x 205, dtype: object,
#  '_item_cache': {},
#  '_attrs': {},
#  '_flags': <Flags(allows_duplicate_labels=True)>}

# %%
cars.make
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
#           ...
# 200          volvo
# 201          volvo
# 202          volvo
# 203          volvo
# 204          volvo
# Name: make, Length: 205, dtype: object

# %%
two_doors = cars['num-of-doors'] == 'two'
body_style_convertible = cars['body-style'] == 'convertible'
fuel_type_gas = cars['fuel-type'] == 'gas'

# %%
cars[two_doors & fuel_type_gas & body_style_convertible]
# Out:
#      symboling  normalized-losses           make fuel-type aspiration  \
# 0            3                NaN    alfa-romero       gas        std
# 1            3                NaN    alfa-romero       gas        std
# 72           3              142.0  mercedes-benz       gas        std
# 128          3                NaN        porsche       gas        std
# 172          2              134.0         toyota       gas        std
# 189          3                NaN     volkswagen       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# 1            two  convertible          rwd           front        88.6
# 72           two  convertible          rwd           front        96.6
# 128          two  convertible          rwd            rear        89.5
# 172          two  convertible          rwd           front        98.4
# ...

# %%
cars[(cars['num-of-doors'] == 'two') & (cars['body-style'] == 'convertible')]
# Out:
#      symboling  normalized-losses           make fuel-type aspiration  \
# 0            3                NaN    alfa-romero       gas        std
# 1            3                NaN    alfa-romero       gas        std
# 72           3              142.0  mercedes-benz       gas        std
# 128          3                NaN        porsche       gas        std
# 172          2              134.0         toyota       gas        std
# 189          3                NaN     volkswagen       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# 1            two  convertible          rwd           front        88.6
# 72           two  convertible          rwd           front        96.6
# 128          two  convertible          rwd            rear        89.5
# 172          two  convertible          rwd           front        98.4
# ...

# %%
cars
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 2            1                NaN  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1               95.0        volvo       gas        std
# 201         -1               95.0        volvo       gas      turbo
# 202         -1               95.0        volvo       gas        std
# 203         -1               95.0        volvo    diesel      turbo
# 204         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
cars
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 2            1                NaN  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1               95.0        volvo       gas        std
# 201         -1               95.0        volvo       gas      turbo
# 202         -1               95.0        volvo       gas        std
# 203         -1               95.0        volvo    diesel      turbo
# 204         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
cars
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 2            1                NaN  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1               95.0        volvo       gas        std
# 201         -1               95.0        volvo       gas      turbo
# 202         -1               95.0        volvo       gas        std
# 203         -1               95.0        volvo    diesel      turbo
# 204         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
cars.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
cars['price'] = cars['price'].astype(float)

# %%
cars.describe()['price']
# Out:
# count      201.000000
# mean     13207.129353
# std       7947.066342
# min       5118.000000
# 25%       7775.000000
# 50%      10295.000000
# 75%      16500.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
#cars['price'].fillna(cars.describe()['price'].median(), inplace=True)

# %%
cars['taxa'] = cars['price'] * 0.3

# %%
for i, row in cars.iterrows():
    print(i)
    print(row['num-of-doors'])
    if row['num-of-doors'] == 'two':
        cars.iloc[i]['taxa'] = row['price']  * 0.2
    if row['num-of-doors'] == 'four':
        cars.iloc[i]['taxa'] = row['price'] * 0.4
# Out:
# 0
# two
# 1
# two
# 2
# two
# 3
# four
# 4
# four
# 5
# two
# 6
# four
# 7
# four
# 8
# four
# 9
# two
# 10
# two
# 11
# four
# 12
# two
# 13
# four
# 14
# four
# 15
# four
# 16
# two
# 17
# four
# 18
# two
# 19
# two
# 20
# four
# 21
# two
# 22
# two
# 23
# two
# 24
# four
# 25
# four
# 26
# four
# 27
# nan
# 28
# four
# 29
# two
# 30
# two
# 31
# two
# 32
# two
# 33
# two
# 34
# two
# 35
# four
# 36
# four
# 37
# two
# 38
# two
# 39
# four
# 40
# four
# 41
# four
# 42
# two
# 43
# four
# 44
# two
# 45
# four
# 46
# two
# 47
# four
# 48
# four
# 49
# two
# 50
# two
# 51
# two
# 52
# two
# 53
# four
# 54
# four
# 55
# two
# 56
# two
# 57
# two
# 58
# two
# 59
# two
# 60
# four
# 61
# two
# 62
# four
# 63
# nan
# 64
# four
# 65
# four
# 66
# four
# 67
# four
# 68
# four
# 69
# two
# 70
# four
# 71
# four
# 72
# two
# 73
# four
# 74
# two
# 75
# two
# 76
# two
# 77
# two
# 78
# two
# 79
# two
# 80
# two
# 81
# two
# 82
# two
# 83
# two
# 84
# two
# 85
# four
# 86
# four
# 87
# four
# ...

# %%
cars['pct_taxa'] = 0

# %%
dict_taxas = {
    'two': 0.2,
    'four': 0.4
}

# %%
dict_taxas.get('two')
# Out:
# 0.2

# %%
cars['num-of-doors'].unique()
# Out:
# array(['two', 'four', nan], dtype=object)

# %%
cars['pct_taxa'] = cars['num-of-doors'].map(dict_taxas)

# %%
cars.groupby(['body-style', 'num-of-doors'])['num-of-doors'].count()
# Out:
# body-style   num-of-doors
# convertible  two              6
# hardtop      two              8
# hatchback    four            10
#              two             60
# sedan        four            79
#              two             15
# wagon        four            25
# Name: num-of-doors, dtype: int64

# %%
cars[\
    (cars['body-style'] == 'sedan') & \
    (cars['aspiration'] == 'std') & \
    (cars['make'] == 'mazda')]\
    ['num-of-doors'].value_counts()
# Out:
# four    6
# Name: num-of-doors, dtype: int64

# %%
cars['num-of-doors'].value_counts(normalize=True)
# Out:
# four    0.561576
# two     0.438424
# Name: num-of-doors, dtype: float64

# %%
cars[cars['num-of-doors'].isnull()]
# Out:
#     symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 27          1              148.0  dodge       gas      turbo          NaN
# 63          0                NaN  mazda    diesel        std          NaN
#
#    body-style drive-wheels engine-location  wheel-base  length  width  height  \
# 27      sedan          fwd           front        93.7   157.3   63.8    50.6
# 63      sedan          fwd           front        98.8   177.8   66.5    55.5
#
#     curb-weight engine-type num-of-cylinders  engine-size fuel-system  bore  \
# 27         2191         ohc             four           98        mpfi  3.03
# 63         2443         ohc             four          122         idi  3.39
#
#    stroke  compression-ratio horsepower peak-rpm  city-mpg  highway-mpg  \
# 27   3.39                7.6        102     5500        24           30
# 63   3.39               22.7         64     4650        36           42
#
#       price    taxa  pct_taxa
# ...

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
cars['num-of-doors'][cars['num-of-doors'].isnull()] = 'four'

# %%
cars.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          0
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# taxa                  4
# pct_taxa              2
# dtype: int64

# %%
cars['pct_taxa'] = cars['num-of-doors'].map(dict_taxas)

# %%
cars['nova_taxa'] = cars['price'] * cars['pct_taxa']

# %%
cars.T
# Out:
#                            0            1            2        3        4    \
# symboling                    3            3            1        2        2
# normalized-losses          NaN          NaN          NaN    164.0    164.0
# make               alfa-romero  alfa-romero  alfa-romero     audi     audi
# fuel-type                  gas          gas          gas      gas      gas
# aspiration                 std          std          std      std      std
# num-of-doors               two          two          two     four     four
# body-style         convertible  convertible    hatchback    sedan    sedan
# drive-wheels               rwd          rwd          rwd      fwd      4wd
# engine-location          front        front        front    front    front
# wheel-base                88.6         88.6         94.5     99.8     99.4
# length                   168.8        168.8        171.2    176.6    176.6
# ...

# %%
cars
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 2            1                NaN  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1               95.0        volvo       gas        std
# 201         -1               95.0        volvo       gas      turbo
# 202         -1               95.0        volvo       gas        std
# 203         -1               95.0        volvo    diesel      turbo
# 204         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
cars['price'].describe()

# > 10000 60%
# senao 30%
# Out:
# count      201.000000
# mean     13207.129353
# std       7947.066342
# min       5118.000000
# 25%       7775.000000
# 50%      10295.000000
# 75%      16500.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
def calcula_taxa(price, limiar=10000):
    if price > limiar:
        return 0.6
    return 0.3

# %%
calcula_taxa(9000, 8000)
# Out:
# 0.6

# %%
cars['nova_taxa'] = cars['price'].apply(calcula_taxa)

# %%
calcula_taxa
# Out:
# <function __main__.calcula_taxa(price, limiar=10000)>

# %%
LIMIAR = 10000
cars['nova_taxa'] = cars['price'].apply(lambda x: 0.3 if x < LIMIAR else 0.6)

# %%
cars['nova_taxa'] = cars['price'].apply(lambda x: calcula_taxa(x, 9000))

# %%
cars[['price']]
# Out:
#        price
# 0    13495.0
# 1    16500.0
# 2    16500.0
# 3    13950.0
# 4    17450.0
# ..       ...
# 200  16845.0
# 201  19045.0
# 202  21485.0
# 203  22470.0
# 204  22625.0
#
# [205 rows x 1 columns]

# %%
cars['price']
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %%
cars.rename({'make':'marca'}, axis=1, inplace=True)

# %%
cars['make']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/infnet/github/.infnet/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/infnet/github/.infnet/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/infnet/github/.infnet/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'make'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
comments_df_t['sentiment'] = 



comments_df_t.apply(lambda row: Score_sentiment(row['comment_normalized']), axis=1) 


comments_df['comment_normalized'].apply(Score_sentiment)

# %%
cars['price'].apply(lambda x: )
# Out:
#      symboling  normalized-losses        marca fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 2            1                NaN  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1               95.0        volvo       gas        std
# 201         -1               95.0        volvo       gas      turbo
# 202         -1               95.0        volvo       gas        std
# 203         -1               95.0        volvo    diesel      turbo
# 204         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
cars.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# marca                 0
# fuel-type             0
# aspiration            0
# num-of-doors          0
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# taxa                  4
# pct_taxa              0
# nova_taxa             0
# dtype: int64

# %%
#cars[cars['price'].isnull()]
